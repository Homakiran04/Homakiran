# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the dataset.
df = pd.read_csv('Space_server.csv')
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# ...

# %%
# Head of the data. 
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# ...

# %%
# Columns of the data.
df.columns
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %%
# Information of the data.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
# objid        10000 non-null float64
# ra           10000 non-null float64
# dec          10000 non-null float64
# u            10000 non-null float64
# g            10000 non-null float64
# r            10000 non-null float64
# i            10000 non-null float64
# z            10000 non-null float64
# run          10000 non-null int64
# rerun        10000 non-null int64
# camcol       10000 non-null int64
# field        10000 non-null int64
# specobjid    10000 non-null float64
# class        10000 non-null object
# redshift     10000 non-null float64
# plate        10000 non-null int64
# mjd          10000 non-null int64
# fiberid      10000 non-null int64
# dtypes: float64(10), int64(7), object(1)
# memory usage: 1.4+ MB

# %%
# Data types of the data
df.dtypes
# Out:
# objid        float64
# ra           float64
# dec          float64
# u            float64
# g            float64
# r            float64
# i            float64
# z            float64
# run            int64
# rerun          int64
# camcol         int64
# field          int64
# specobjid    float64
# class         object
# redshift     float64
# plate          int64
# mjd            int64
# fiberid        int64
# dtype: object

# %% [markdown]
# Observation :
#
#     Catergorical features : ('class')
#     Numerical features : Except class column all columns are in numerical values.

# %%
# Finding sum of null values
df.isnull().sum()
# Out:
# objid        0
# ra           0
# dec          0
# u            0
# g            0
# r            0
# i            0
# z            0
# run          0
# rerun        0
# camcol       0
# field        0
# specobjid    0
# class        0
# redshift     0
# plate        0
# mjd          0
# fiberid      0
# dtype: int64

# %% [markdown]
# Observation:
#     There are no null values from any columns.

# %%
# Describing the dataset through statistical analysis. 
df.describe()
# Out:
#               objid            ra           dec             u             g  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.237650e+18    175.529987     14.836148     18.619355     17.371931
# std    1.577039e+05     47.783439     25.212207      0.828656      0.945457
# min    1.237650e+18      8.235100     -5.382632     12.988970     12.799550
# 25%    1.237650e+18    157.370946     -0.539035     18.178035     16.815100
# 50%    1.237650e+18    180.394514      0.404166     18.853095     17.495135
# 75%    1.237650e+18    201.547279     35.649397     19.259232     18.010145
# max    1.237650e+18    260.884382     68.542265     19.599900     19.918970
#
#                   r             i             z           run    rerun  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.0
# mean      16.840963     16.583579     16.422833    981.034800    301.0
# ...

# %%
# Value counts of the column class to know how many counts and dtype.
df['class'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         STAR
# 1         STAR
# 2       GALAXY
# 3         STAR
# 4         STAR
#          ...
# 9995    GALAXY
# 9996    GALAXY
# 9997      STAR
# 9998    GALAXY
# 9999    GALAXY
# Name: class, Length: 10000, dtype: object>

# %%
# Visualizing the null values of the dataset. 
sns.heatmap(df.isnull())

# %% [markdown]
# Observation :
#
#     There are no null values in dataset by visualizing through heatmap.

# %%
# Correlation of the dataset. 
df.corr()
# Out:
#                   objid            ra           dec             u  \
# objid      1.000000e+00  2.524419e-14 -1.937483e-15  5.581214e-14
# ra         2.524419e-14  1.000000e+00  3.596046e-03  3.123756e-02
# dec       -1.937483e-15  3.596046e-03  1.000000e+00  3.527932e-02
# u          5.581214e-14  3.123756e-02  3.527932e-02  1.000000e+00
# g          1.001149e-13  4.390863e-02  6.187471e-02  8.492320e-01
# r          2.995673e-14  4.710290e-02  6.340395e-02  6.923790e-01
# i          2.212198e-14  4.573107e-02  5.829189e-02  6.026302e-01
# z         -4.107700e-14  4.294957e-02  5.687030e-02  5.514828e-01
# run       -1.553011e-14 -9.274056e-02  7.783849e-01  3.822910e-02
# rerun               NaN           NaN           NaN           NaN
# camcol     1.921887e-15 -6.293831e-03  1.146139e-01  9.944672e-03
# field      5.938881e-16  5.946996e-01 -1.314714e-01  8.547880e-03
# specobjid -1.829075e-15 -9.532711e-02  8.834533e-02 -1.294293e-01
# ...

# %% [markdown]
# Observation :
#      -> correleation contains Nan value which represents the repeated same value for the entire column.

# %%
# Visualizing the correlation through heatmap.
plt.figure(figsize=(10,8))
sns.heatmap(df.corr())

# %%
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# ...

# %%
# Visualizing the Plate column through distribution plot.
plt.figure(figsize=(20,8))
sns.distplot(df['plate'])

# %%
# Visualizing the 'u' column through distribution plot.
plt.figure(figsize=(20,8))
sns.distplot(df['u'])

# %% [markdown]
# Observation :
#
# --> The better of DeV/Exp magnitude fit(u) is Negatively Skewed.

# %%
# Visualizing the 'g' column through distribution plot.
plt.figure(figsize=(20,8))
sns.distplot(df['g'])

# %% [markdown]
# Observation :
#
# --> The better of DeV/Exp magnitude fit(g) is Negatively Skewed.

# %%
# Visualizing the 'r' column through distribution plot.
plt.figure(figsize=(20,8))
sns.distplot(df['r'])

# %% [markdown]
# Observation :
#
# --> The better of DeV/Exp magnitude fit(r) is Normally distributed.

# %%
# Visualizing the 'i' column through distribution plot.
plt.figure(figsize=(20,8))
sns.distplot(df['i'])

# %% [markdown]
# Observation :
#
# --> The better of DeV/Exp magnitude fit(i) is Normally distributed.

# %%
# Visualizing the 'z' column through distribution plot.
plt.figure(figsize=(20,8))
sns.distplot(df['z'])

# %% [markdown]
# Observation :
#
#     --> The better of DeV/Exp magnitude fit(z) is Normally distributed.

# %%
# Visualizing the scatter plot between 'r' and 'ra'.
sns.scatterplot(df['r'],df['ra'])

# %% [markdown]
# Observation :
#     --> From scatter plot visualization we observed that Maximum of the points are between 14 to 20.

# %%
# Visualizing the scatter plot between 'u' and 'ra'.
sns.scatterplot(df['u'],df['ra'])

# %% [markdown]
# Observation :
#     --> From scatter plot visualization we observed that Maximum of the points are between 16 to 19.5.

# %%
# Visualizing the scatter plot between 'i' and 'ra'.
sns.scatterplot(df['i'],df['ra'])

# %% [markdown]
# Observation :
#     --> From scatter plot visualization we observed that Maximum of the points are between 14 to 20.

# %%
# Visualizing the scatter plot between 'z' and 'ra'.
sns.scatterplot(df['z'],df['ra'])

# %% [markdown]
# Observation :
#     --> From scatter plot visualization we observed that Maximum of the points are between 12.5 to 20.5.

# %%
# Visualizing the scatter plot between 'g' and 'ra'.
sns.scatterplot(df['g'],df['ra'])

# %% [markdown]
# Observation :
#     --> From scatter plot visualization we observed that Maximum of the points are between 14.5 to 19.5.

# %%
# Visualizing the 'z' vs 'class' through bar plot 
sns.barplot(df['z'],df['class'])

# %% [markdown]
# Observation :
#     --> From above bar plot visualization QSO class is maximum and Galaxy class is low with respect to 'z'.

# %%
# Visualizing the 'u' vs 'class' through bar plot 
sns.barplot(df['u'],df['class'])

# %% [markdown]
# Observation : --> From above bar plot visualization QSO class is maximum and STAR class is low with respect to 'u'.

# %%
# Visualizing the 'g' vs 'class' through bar plot 
sns.barplot(df['g'],df['class'])

# %% [markdown]
# Observation : --> From above bar plot visualization QSO class is maximum and Galaxy class is low with respect to 'g'.

# %%
# Visualizing the 'r' vs 'class' through bar plot 
sns.barplot(df['r'],df['class'])

# %% [markdown]
# Observation : --> From above bar plot visualization QSO class is maximum and Galaxy class is low with respect to 'r'.

# %%
# Visualizing the 'i' vs 'class' through bar plot 
sns.barplot(df['i'],df['class'])

# %% [markdown]
# Observation : --> From above bar plot visualization QSO class is maximum and Galaxy class is low with respect to 'i'.

# %%
# Visualizing the 'u' vs 'class' through violin plot.
sns.violinplot(x='u',y='class',data=df)

# %%
# Visualizing the 'g' vs 'class' through violin plot.
sns.violinplot(df['g'],df['class'])

# %%
# Visualizing the 'r' vs 'class' through violin plot.
sns.violinplot(df['r'],df['class'])

# %%
# Visualizing the 'i' vs 'class' through violin plot.
sns.violinplot(df['i'],df['class'])

# %% [markdown]
# Observation :
#     --> From the above figure the 'u' column is positively skewed.

# %%
# Visualizing the 'u' vs 'dec' through kde plot.
sns.kdeplot(df['u'],df['dec'])

# %%
# Visualizing the 'r' vs 'dec' through kde plot.
sns.kdeplot(df['r'],df['dec'])

# %%
# Visualizing the 'g' vs 'dec' through kde plot.
sns.kdeplot(df['g'],df['dec'])

# %%
# Visualizing the 'i' vs 'dec' through kde plot.
sns.kdeplot(df['i'],df['dec'])

# %%
# Visualizing the 'z' vs 'dec' through kde plot.
sns.kdeplot(df['z'],df['dec'])

# %%
# checking Head of the data.
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# ...

# %%
# Visualizing boxplot for 'ra' column to find outliers in the dataset.
sns.boxplot(df['ra'])

# %%
# Visualizing boxplot for 'dec' column to find outliers in the dataset.
sns.boxplot(df['dec'])

# %%
# Visualizing the outliers of all columns through boxplot.
df.plot(kind='box',subplots = True, layout=(4,5),figsize = (10,20))
# Out:
# objid            AxesSubplot(0.125,0.71587;0.133621x0.16413)
# ra            AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# dec            AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# u             AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# g             AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# r               AxesSubplot(0.125,0.518913;0.133621x0.16413)
# i            AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# z             AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# run          AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# rerun        AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# camcol          AxesSubplot(0.125,0.321957;0.133621x0.16413)
# field        AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# specobjid     AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# redshift     AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# plate        AxesSubplot(0.766379,0.321957;0.133621x0.16413)
# ...

# %%
# Visualizing the 'u' column with histogram.
plt.hist(df['u'])
# Out:
# (array([2.000e+00, 1.000e+00, 5.000e+00, 2.400e+01, 1.100e+02, 3.480e+02,
#         8.320e+02, 1.482e+03, 2.643e+03, 4.553e+03]),
#  array([12.98897 , 13.650063, 14.311156, 14.972249, 15.633342, 16.294435,
#         16.955528, 17.616621, 18.277714, 18.938807, 19.5999  ]),
#  <a list of 10 Patch objects>)

# %%
 # Visualizing the 'g' column with histogram.
plt.hist(df['g'])
# Out:
# (array([   6.,   14.,  111.,  394.,  914., 1843., 3139., 2690.,  717.,
#          172.]),
#  array([12.79955 , 13.511492, 14.223434, 14.935376, 15.647318, 16.35926 ,
#         17.071202, 17.783144, 18.495086, 19.207028, 19.91897 ]),
#  <a list of 10 Patch objects>)

# %%
# Visualizing the 'r' column with histogram.
plt.hist(df['r'])
# Out:
# (array([2.000e+01, 3.790e+02, 2.005e+03, 4.555e+03, 2.463e+03, 5.690e+02,
#         7.000e+00, 0.000e+00, 0.000e+00, 2.000e+00]),
#  array([12.4316  , 13.668644, 14.905688, 16.142732, 17.379776, 18.61682 ,
#         19.853864, 21.090908, 22.327952, 23.564996, 24.80204 ]),
#  <a list of 10 Patch objects>)

# %%
# Visualizing the 'i' column with histogram.
plt.hist(df['i'])
# Out:
# (array([3.600e+01, 1.010e+03, 4.851e+03, 3.471e+03, 6.140e+02, 1.300e+01,
#         1.000e+00, 3.000e+00, 0.000e+00, 1.000e+00]),
#  array([11.94721 , 13.570452, 15.193694, 16.816936, 18.440178, 20.06342 ,
#         21.686662, 23.309904, 24.933146, 26.556388, 28.17963 ]),
#  <a list of 10 Patch objects>)

# %%
# Importing label encoder to convert non-numeric values to numeric.
from sklearn.preprocessing import LabelEncoder

# %%
# Applying the label encoder.
Le = LabelEncoder()

# %%
# Fitting the label encoder with fit transform and unique function.
df['class'] = Le.fit_transform(df['class'])
df['class'].unique()
# Out:
# array([2, 0, 1], dtype=int64)

# %%
# Checking the Converted column.
df['class']
# Out:
# 0       2
# 1       2
# 2       0
# 3       2
# 4       2
#        ..
# 9995    0
# 9996    0
# 9997    2
# 9998    0
# 9999    0
# Name: class, Length: 10000, dtype: int32

# %%
# Final checking as head of the data.
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid  class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18      2 -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17      2 -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17      0  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18      2 -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18      2  0.000590   3306
#
#      mjd  fiberid
# ...

# %%
# Splitting the data into training and testing set with train_test_split.
from sklearn.model_selection import train_test_split

# %%
# Defining and creating X variable.
X = df.drop('class',axis=1)
X
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid  redshift  \
# ...

# %%
# Defining and creating y variable.
y = df['class']
y
# Out:
# 0       2
# 1       2
# 2       0
# 3       2
# 4       2
#        ..
# 9995    0
# 9996    0
# 9997    2
# 9998    0
# 9999    0
# Name: class, Length: 10000, dtype: int32

# %%
# To ignore warnings.
import warnings
warnings.simplefilter('ignore')

# %%
# Splitting the dataset into training and testing.
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)

# %%
# Importing Logisticregression algorithm to predict the model.
from sklearn.linear_model import LogisticRegression

# %%
# Fitting the model. 
Lr = LogisticRegression()
Lr.fit(X_train,y_train)
y_pred = Lr.predict(X_test)

# %%
# Predicted Values.
y_pred
# Out:
# array([2, 2, 0, ..., 2, 2, 2])

# %%
# Score of the training model. 
Lr.score(X_train,y_train)
# Out:
# 0.797

# %%
# Accuracy of the model.
from sklearn import metrics
from sklearn.metrics import accuracy_score
print('Accuracy:',metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.7963333333333333

# %%
# Finding Confusion matrix and classification report to the model.
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[1471    0   37]
#  [ 209    0   45]
#  [ 320    0  918]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.98      0.84      1508
#            1       0.00      0.00      0.00       254
#            2       0.92      0.74      0.82      1238
#
#     accuracy                           0.80      3000
#    macro avg       0.55      0.57      0.55      3000
# weighted avg       0.75      0.80      0.76      3000

# %%
# Finding Cross validation to reduce under-fitting and over-fitting model.
from sklearn.model_selection import cross_val_score
cross_val_score(LogisticRegression(),X,y,cv=5,scoring='accuracy').mean()
# Out:
# 0.7967968104242026

# %%
# Boosting the accuracy through boosting algorithms.
# We are using directly gradient boosting classifier.
from sklearn.ensemble import GradientBoostingClassifier

# %%
# Importing the gradient boosting model.
Gr = GradientBoostingClassifier()

# %%
# Fitting the model.
Gr.fit(X_train,y_train)
ygr_pred = Gr.predict(X_test)

# %%
# Getting Accuracy,confusion_matrix and classification report to the model.
Gr.score(X_train,y_train)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[1471    0   37]
#  [ 209    0   45]
#  [ 320    0  918]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.98      0.84      1508
#            1       0.00      0.00      0.00       254
#            2       0.92      0.74      0.82      1238
#
#     accuracy                           0.80      3000
#    macro avg       0.55      0.57      0.55      3000
# weighted avg       0.75      0.80      0.76      3000

# %%
# Cross-validation to the model.
from sklearn.model_selection import cross_val_score
cross_val_score(Gr,X,y,cv=5,scoring='accuracy').mean()
# Out:
# 0.9891992978498244

# %%
# Saving the model as a pickle in the file.
from sklearn.externals import joblib
joblib.dump(LogisticRegression,'Space_Server.pkl')
# Out:
# ['Space_Server.pkl']

# %% [markdown]
# Thank You...!
